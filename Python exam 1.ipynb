# %% [markdown]
# Name: Sonjoy Paul

# %% [markdown]
# <center> <h1> <font color='black'> Problem  <font> </h1> </center>

# %% [markdown]
# <h1> <font color='black'> Definig Variable   <font> </h1>

# %%
h= 6 # Height
q= 40 # Design discharge
Cd= 0.6 # Discharge Cofficient
g= 32.2 # Gravity
pi= 3.1416

# %% [markdown]
# <h1> <font color='black'> importing library  <font> </h1>

# %%
import numpy as np

# %%
x = 32*q/(pi*pi)*Cd*Cd*g # equation 
print (x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 x = 32*q/(pi*pi)*Cd*Cd*g # equation
#       3 print (x)
#
# NameError: name 'q' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 print (x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# <center> <h1> <font color='black'> Problem 2 <font> </h1> </center>

# %% [markdown]
# <h1> <font color='black'> importing library  <font> </h1>

# %%
import pandas as pd
import geopandas as gpd

# %%
a = gpd.read_file("D:\\python\\population_data.csv") #call the csv file of populatin
a
# Out:
#     table with row headers in column B and column headers in rows 3 through 4  \
# 0    Annual Estimates of the Resident Population fo...
# 1                                                 Rank
# 2
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 791  Note: Areas are included in this table if they...
# 792                                Suggested Citation:
# 793  Annual Estimates of the Resident Population fo...
# 794    Source: U.S. Census Bureau, Population Division
# 795                             Release Date: May 2020
#
#                           field_2        field_3         field_4  \
# 0
# 1                 Geographic Area  April 1, 2010
# 2                                         Census  Estimates Base
# 3         New York city, New York      8,175,133       8,175,031
# 4    Los Angeles city, California      3,792,621       3,793,139
# ...
